# %% [markdown]
# # Figure panels for eQTL results

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dat_dir = "/usersdata/yuanhua/msNewData/fromMarc/"

# %% [markdown]
# ### Tissue colocalization

# %%
df_mat = pd.read_csv(dat_dir + 'TissueColocalization_Mat_ratio.txt', 
                     sep='\t', index_col=0)

# %%
df_mat
# Out:
#                             Bcells_rf  CD4_T_cells_rf  CD4_Treg_cells_rf  \
# Bcells_rf                    1.000000        0.120000           0.080000
# CD4_T_cells_rf               0.011442        1.000000           0.054920
# CD4_Treg_cells_rf            0.031250        0.218750           1.000000
# CD8_gd_Tcells_rf             0.030303        0.030303           0.030303
# CD8_T_cells_rf               0.027778        0.289683           0.071429
# cDC2_cells_rf                0.075269        0.204301           0.118280
# Macrophage_cells_rf          0.074627        0.208955           0.089552
# MALAT1Low_myeloid_cells_rf   0.045455        0.068182           0.045455
# Monocyte_cells_rf            0.057971        0.086957           0.043478
# NKcells_rf                   0.050847        0.220339           0.118644
# pDCcells_rf                  0.095238        0.095238           0.095238
#
#                             CD8_gd_Tcells_rf  CD8_T_cells_rf  cDC2_cells_rf  \
# Bcells_rf                           0.000000        0.160000       0.160000
# CD4_T_cells_rf                      0.004577        0.180778       0.048055
# CD4_Treg_cells_rf                   0.046875        0.203125       0.156250
# CD8_gd_Tcells_rf                    1.000000        0.030303       0.060606
# CD8_T_cells_rf                      0.007937        1.000000       0.083333
# cDC2_cells_rf                       0.021505        0.215054       1.000000
# Macrophage_cells_rf                 0.014925        0.238806       0.253731
# MALAT1Low_myeloid_cells_rf          0.022727        0.068182       0.090909
# Monocyte_cells_rf                   0.014493        0.115942       0.159420
# NKcells_rf                          0.033898        0.186441       0.152542
# pDCcells_rf                         0.047619        0.119048       0.166667
#
#                             Macrophage_cells_rf  MALAT1Low_myeloid_cells_rf  \
# Bcells_rf                              0.160000                    0.080000
# CD4_T_cells_rf                         0.041190                    0.011442
# CD4_Treg_cells_rf                      0.093750                    0.046875
# CD8_gd_Tcells_rf                       0.030303                    0.030303
# CD8_T_cells_rf                         0.071429                    0.019841
# cDC2_cells_rf                          0.225806                    0.064516
# Macrophage_cells_rf                    1.000000                    0.074627
# MALAT1Low_myeloid_cells_rf             0.090909                    1.000000
# Monocyte_cells_rf                      0.159420                    0.043478
# NKcells_rf                             0.135593                    0.016949
# pDCcells_rf                            0.095238                    0.047619
#
#                             Monocyte_cells_rf  NKcells_rf  pDCcells_rf
# Bcells_rf                            0.120000    0.080000     0.080000
# CD4_T_cells_rf                       0.020595    0.034325     0.013730
# CD4_Treg_cells_rf                    0.046875    0.109375     0.078125
# CD8_gd_Tcells_rf                     0.030303    0.090909     0.060606
# CD8_T_cells_rf                       0.031746    0.047619     0.023810
# cDC2_cells_rf                        0.129032    0.118280     0.086022
# Macrophage_cells_rf                  0.149254    0.089552     0.074627
# MALAT1Low_myeloid_cells_rf           0.068182    0.022727     0.045455
# Monocyte_cells_rf                    1.000000    0.057971     0.028986
# NKcells_rf                           0.067797    1.000000     0.084746
# pDCcells_rf                          0.047619    0.071429     1.000000

# %%
import seaborn as sns

fig_dir = '/usersdata/yuanhua/msNewData/fromMarc/figures/'

fig = plt.figure(figsize=(9, 7), dpi=300)
ax = sns.heatmap(df_mat, cmap="YlGnBu", annot=True, fmt=".2f")
plt.title('Proportion of overlapped eQTLs between cell types')

plt.tight_layout()
# plt.savefig(fig_dir + 'TissueColocalization.pdf')
plt.show()

# %% [markdown]
# ## Heatmatp eQTL

# %%
df_fdr = pd.read_csv(dat_dir + 'HeatmapInformation/SigColocFdr.txt', sep='\t')
df_beta = pd.read_csv(dat_dir + 'HeatmapInformation/SigColocBeta.txt', sep='\t')

# %%
df_fdr = df_fdr.drop(index='6_32397309-HLA-DRB5')
df_beta = df_beta.drop(index='6_32397309-HLA-DRB5')

# %%
df_fdr
# Out:
#                        B_cell   CD4+_T_cell  CD4+_Treg_cell  CD8+_gd_T_cell  \
# 6_135798845-AHI1     0.361436  1.025205e-03        0.145146        0.490220
# 6_32605884-HLA-DQB1  0.000858  6.075174e-03        0.343228        0.216168
# 6_31583155-AIF1      0.842590  2.509557e-03        0.568546        0.798034
# 17_38023745-ORMDL3   0.206558  7.981869e-04        0.133548        0.358894
# 7_138729795-ZC3HAV1  0.461224  1.053258e-10        0.000322        0.207097
# 12_9876091-CLECL1    0.040202  1.242588e-04        0.048150        0.003349
# 6_32611982-HLA-DQA2  0.000011  6.595753e-05        0.001136        0.244447
# 11_309127-IFITM2     0.346322  3.538264e-05        0.123221        0.011450
#
#                       CD8+_T_cell          cDC2    Macrophage  \
# 6_135798845-AHI1     5.361172e-02  8.984803e-02  9.484946e-01
# 6_32605884-HLA-DQB1  1.484594e-07  6.725315e-05           NaN
# 6_31583155-AIF1      3.861848e-09  5.904924e-01  5.235176e-01
# 17_38023745-ORMDL3   6.926391e-05  7.815259e-01  3.700149e-01
# 7_138729795-ZC3HAV1  1.374096e-04  1.709413e-01  2.676756e-01
# 12_9876091-CLECL1    5.234030e-13  1.390071e-07  1.682631e-05
# 6_32611982-HLA-DQA2  5.283081e-11  9.277593e-08  1.070450e-10
# 11_309127-IFITM2     3.410461e-06  8.279950e-01  4.932241e-01
#
#                      MALAT1Low_myeloid_cell  Monocyte   NK_cell           pDC
# 6_135798845-AHI1               8.760951e-01  0.262906  0.348963  6.975246e-01
# 6_32605884-HLA-DQB1            5.856937e-02  0.302729  0.641055  3.284498e-02
# 6_31583155-AIF1                3.969303e-01  0.981359  0.001103  8.571882e-01
# 17_38023745-ORMDL3             4.828632e-01  0.123772  0.521421  1.089939e-01
# 7_138729795-ZC3HAV1            4.580288e-01  0.326438  0.013678  4.607126e-01
# 12_9876091-CLECL1              1.962343e-03  0.000019  0.513192  1.383709e-04
# 6_32611982-HLA-DQA2            5.284776e-09  0.000073  0.012007  1.587728e-13
# 11_309127-IFITM2               7.576710e-01  0.031366  0.094491  3.501619e-01

# %%
import seaborn as sns
#sns.set_theme()

# fig = plt.figure(figsize=(7, 5), dpi=300)
fig = plt.figure(figsize=(7, 4.5), dpi=300)
sns.heatmap(df_beta, cmap="RdBu_r", vmin=-1.7, vmax=1.7)
# plt.xticks(np.arange(11) + 0.5, res_comb['cells'], rotation=30, ha='right')
# plt.yticks(np.arange(len(gene_idx)) + 0.5, 
#            np.array(res_comb['SNP_gene_list'])[gene_idx], rotation=0)
plt.xticks(rotation=30, ha='right')
plt.title("Effect size of cis-eQTL; MS SNPs")

idx3 = np.where(df_fdr.values < 0.001)
idx2 = np.where((df_fdr.values >= 0.001) * 
                (df_fdr.values < 0.01))
idx1 = np.where((df_fdr.values >= 0.01) * 
                (df_fdr.values < 0.1))

for ii in range(len(idx1[0])):
    plt.annotate("*", (idx1[1][ii] + 0.5, idx1[0][ii] + 0.6), 
                 ha='center', va='center')
    
for ii in range(len(idx2[0])):
    plt.annotate("**", (idx2[1][ii] + 0.5, idx2[0][ii] + 0.6), 
                 ha='center', va='center')
    
for ii in range(len(idx3[0])):
    plt.annotate("***", (idx3[1][ii] + 0.5, idx3[0][ii] + 0.6), 
                 ha='center', va='center')

plt.tight_layout()
# plt.savefig(fig_dir + 'Effect_Size_eQTL.pdf')
plt.show()

# %% [markdown]
# ## Summary

# %%
df_stats = pd.read_csv(dat_dir + 'eQTL_summary.txt', sep='\t')
idx = np.argsort(df_stats['# eQTL'].values)[::-1]
df_stats = df_stats.loc[idx]
df_stats.index = range(df_stats.shape[0])

# %%
df_stats['Overall rate'][df_stats['Overall rate'] == '-'] = '0%'
df_stats['Overall rate'] = [float(x[:-1]) / 100 for x in 
                            df_stats['Overall rate']]

df_stats['Overall rep'] = np.round(
    df_stats['Overlap Overall'] * df_stats['Overall rate'])
# Out:
# /home/yuanhua/.conda/envs/TFProb/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_stats
# Out:
#              Cell type  # donors  # eQTL  Replicated vd Wijst  \
# 0           CD4 T cell        82     437                  160
# 1           CD8 T cell        81     252                   72
# 2            cDC2 cell        77      93                    0
# 3             Monocyte        62      69                   17
# 4           Macrophage        67      67                    0
# 5       CD4 T-reg cell        70      64                    0
# 6              NK cell        72      59                   17
# 7   MALAT1-low myeloid        77      44                    0
# 8             pDC cell        52      42                    0
# 9          CD8 gd cell        60      33                    0
# 10              B cell        42      25                    5
#
#     Replicated Oelen  Overlapped Oelen  Overlap Overall  Overall rate  Novel  \
# 0                210               352              417          0.69  False
# 1                122               203              242          0.79  False
# 2                  0                 0                0          0.00   True
# 3                 34                57               67          0.78  False
# 4                  0                 0               63          0.61  False
# 5                  0                 0               60          0.78  False
# 6                 25                46               56          0.67  False
# 7                  0                 0                0          0.00   True
# 8                 16                39               39          0.41  False
# 9                  0                 0                0          0.00   True
# 10                 5                20               23          0.44  False
#
#     Overall rep
# 0         288.0
# 1         191.0
# 2           0.0
# 3          52.0
# 4          38.0
# 5          47.0
# 6          38.0
# 7           0.0
# 8          16.0
# 9           0.0
# 10         10.0

# %%
import matplotlib.pyplot as plt

novel_cells = list(df_stats['Cell type'][df_stats['Novel']])

x = np.arange(df_stats.shape[0])  # the label locations
width = 0.35  # the width of the bars

fig = plt.figure(figsize=(6, 4),dpi=300)
rects1 = plt.bar(x - width/2, df_stats['# eQTL'], width, label='# Our hits')
rects3 = plt.bar(x + width/2, df_stats['Overlap Overall'], width, 
                 color='gainsboro', label='# Unreplicated')
rects2 = plt.bar(x + width/2, df_stats['Overall rep'], 
                 width, label='# Replicated')


# rects3 = plt.bar(x + width/2, df_stats['Overlapped'], width, 
#                  color='gainsboro', label='# Unreplicated')
# rects2 = plt.bar(x + width/2, df_stats['Replicated Oelen'], 
#                  width, label='# Replicated')

for i in range(len(x)):
    _color = 'k'
    if df_stats['Cell type'][i] in novel_cells:
        _text = 'Novel'
        _color = 'red'
    elif df_stats['Overall rate'][i] > 0:
        _text = '%d%%' %(df_stats['Overall rate'][i] * 100)
    else:
        _text = 'NA'
    plt.text(x[i], df_stats['# eQTL'][i] + 10, _text, c=_color, ha='center')

plt.ylim(0, 490)
plt.xticks(x, df_stats['Cell type'], rotation=30, ha='right')
plt.ylabel('#eQTLs')
plt.legend()
plt.tight_layout()
plt.grid(alpha=0.3)

plt.tight_layout()
# plt.savefig(fig_dir + 'global_eQTL_summary.pdf')
plt.show()

# %% [markdown]
# ## Colocalization plot

# %%
df_gwas = pd.read_csv(dat_dir + 'ColocPlotData/SelectedGWASSumStats.txt', 
                      sep='\t')
df_eqtl = pd.read_csv(dat_dir + 'ColocPlotData/SelectedQTLSumStats.CD8+_T_cell.txt', 
                      sep='\t')

# %%
df_gwas.head()
# Out:
#    CHR        BP        SNP A1 A2   N      OR              P   OR.R.  \
# 0    6  31483136  rs2844495  A  G  15  1.3935   4.040000e-68  1.3935
# 1    6  31483415  rs2844494  A  C  15  0.8037   5.030000e-37  0.8045
# 2    6  31483458  rs9267444  A  G  15  0.9224   4.380000e-06  0.9219
# 3    6  31483481  rs9267445  C  G  15  1.0506   5.658000e-02  1.0438
# 4    6  31483752  rs3131632  G  A  15  0.6676  3.420000e-102  0.6676
#
#             P.R.       Q      I        markerId      ChrPos
# 0   4.040000e-68  0.4545   0.00  6:31483136_A_G  6_31483136
# 1   7.730000e-26  0.1766  25.15  6:31483415_A_C  6_31483415
# 2   3.655000e-03  0.0046  55.62  6:31483458_A_G  6_31483458
# 3   3.044000e-01  0.0038  56.44  6:31483481_C_G  6_31483481
# 4  3.420000e-102  0.8058   0.00  6:31483752_G_A  6_31483752

# %%
df_eqtl.head()
# Out:
#   feature_id     snp_id   p_value      beta   beta_se  \
# 0     IFITM2  rs6598046  0.000001  0.692189  0.143501
# 1     IFITM2  rs1059091  0.000003  0.588850  0.126787
# 2     IFITM2  rs7102856  0.000005  0.629599  0.138235
# 3     IFITM2  rs4029218  0.000005  0.629599  0.138235
# 4     IFITM2  rs7480418  0.000005  0.629599  0.138235
#
#    empirical_feature_p_value  feature_chromosome  feature_start  feature_end  \
# 0                   0.002554                  11         307631       315272
# 1                   0.004459                  11         307631       315272
# 2                   0.005854                  11         307631       315272
# 3                   0.005854                  11         307631       315272
# 4                   0.005854                  11         307631       315272
#
#    strand  ... snp_chromosome snp_position assessed_allele  call_rate  \
# 0       1  ...             11       303271               A          1
# 1       1  ...             11       309127               G          1
# 2       1  ...             11       303148               G          1
# 3       1  ...             11       303631               G          1
# 4       1  ...             11       303537               T          1
#
#         maf     hwe_p  V5  V6     ChrPos               QTL
# 0  0.277778  0.589052   T   A  11_303271  11_303271-IFITM2
# 1  0.314815  0.309146   A   G  11_309127  11_309127-IFITM2
# 2  0.314815  0.796728   A   G  11_303148  11_303148-IFITM2
# 3  0.314815  0.796728   C   G  11_303631  11_303631-IFITM2
# 4  0.314815  0.796728   C   T  11_303537  11_303537-IFITM2
#
# [5 rows x 29 columns]

# %%
_col_gene = 'ZC3HAV1'

_idx2 = df_eqtl.feature_id == _col_gene
_post = np.median(df_eqtl.snp_position[_idx2].values)
_chrom = df_eqtl.feature_chromosome[_idx2].values[0]

_idx1 = ((df_gwas.CHR == _chrom) * 
         (df_gwas.BP >= _post - 100000) *
         (df_gwas.BP <= _post + 100000)
        )

# %%
sum(_idx1)
# Out:
# 349

# %%
fig = plt.figure(figsize=(5, 4.5), dpi=300)
plt.subplot(2, 1, 1)
plt.scatter(df_gwas.BP[_idx1]/1000, 
            -np.log10(df_gwas.P[_idx1]), 
            color='lightseagreen', s=5)
plt.xlim(138729-110, 138729+110)
plt.xticks([])
plt.ylabel('-log10(P), GWAS')

plt.subplot(2, 1, 2)
plt.scatter(df_eqtl.snp_position[_idx2] / 1000, 
            -np.log10(df_eqtl.p_value[_idx2]), 
            color='skyblue', s=5)
plt.xlim(138729-110, 138729+110)
plt.xticks([138650, 138700, 138750, 138800])
plt.xlabel('Chromosome 7 (kb)')
plt.ylabel('-log10(P), eQTL')
plt.tight_layout()

plt.savefig(fig_dir + 'coloc_%s.pdf' %(_col_gene))
plt.show()
